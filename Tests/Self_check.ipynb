# %% [markdown]
# ## Self Check file
# *Created by: Ricky Huang*
#
# - configuration check for the simulation script
# - functional checks for the simulation script

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import math
import sys
sys.path.append('../Utils/')
from Sim1_Util import roundhalf, count_op, plot_QueuesTime, plot_QueueWait, plot_WaitDist, plot_Ptclsta
from Sim13_Init import initialize, sim_run
from Sim13_Check import check

# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
check()

cus_test, op_test, bl_test, ot_test = initialize(
                            x0 = 0, op_num = 2, cus_th = 40, cus_num = 1, 
                            pause_prob = 0, ot = -1, f_ot = -1, f_rls = -1,
                            show = True)
waiting_times, outstand_times, ptcl_fin, ptcl_num, backlog_sz, onthread_sz, ptcl_fincount, ptcl_stacount, op_stacount = sim_run(
                        cus_test, op_test, bl_test, ot_test,
                        cus_lam = 20, cycle = 24, cycle_num = 2, 
                        pause_prob = 0, f_ot = 23, f_rls = -1,
                        poisson = False, ops_num = None,
                        show = False, show_fin = True, count_sta = True, debug = True)
# Out:
# check passed!
# ######################
# initilization finished
# num. of customers: 1
# ptcls on thread: 0
# ptcls backlogged: 0
# operators idle: 2, busy: 0
#
# %%% grab job UE1185 at t= 0
# %%% grab job None at t= 0
# %%% grab job re71392 at t= 1
# %%% finish job UE1185 at t= 23
# %%% job waiting time 0 hours at t= 23
# ### finshed 1 ptcls in cycle 0 ###
# ### remaining 19 ptcls in cycle 1 ###
# %%% grab job XB8764 at t= 24
# %%% finish job re71392 at t= 24
# %%% job waiting time 0 hours at t= 24
# %%% grab job Qm25128 at t= 25
# %%% finish job XB8764 at t= 47
# %%% job waiting time 22 hours at t= 47
# ### finshed 2 ptcls in cycle 1 ###
# ### remaining 37 ptcls in cycle 2 ###

# %%
plot_QueueWait(onthread_sz, waiting_times)
plot_Ptclsta(ptcl_fincount, ptcl_stacount, 40, onthread_sz)
# Out:
# average waiting time: 7.333333333333333 hours
