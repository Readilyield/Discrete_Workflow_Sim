# %% [markdown]
# # Job length testing file
# *created by: Ricky Huang*
#
# - runs simulations based on different average job lengths

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import sys
sys.path.append('../Utils/')
from Sim1_Util import roundhalf, count_op, plot_QueuesTime, plot_QueueWait, plot_WaitDist, plot_Ptclsta
from Sim13_ecl_Init import initialize, sim_run
from Sim13_ecl_Batch import test_func, setup, get_mean, plot_multi_QueuesTime, plot_multi_WaitTime, test_batch_wpic
from Sim13_ecl_Util import data_to_csv, csv_to_jobs, res_to_csv, plot_scatter, csv_to_data, get_multiplier

# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Running $\kappa$ = 0.5, 1, 2, 5
# ## fixing op_num, change job avg. length and scale

# %%
k = 5
path = "../ecldata/ecldata_without_float.csv"
c, f_lam, f_rls = get_multiplier(k, tol = 1e-3, check = True, path = path)
jobs, jobs_prob, mean_ot, total_ot, total_jobs = csv_to_jobs(path, mul=c)
'''rounding up/down lambda acceptable?'''
print(mean_ot+1)
#op_num = (1+eps)*f_lam*(cus_num*1+cus_num*mean_ot)/24

op_nums = csv_to_data("level_curve_dt/1.0ot_op_10ecl_pois_var_1cus.csv",attr='op_num')

tmp = []
epss = np.linspace(0.3,0,31) 
#0.5-0, 26 discrete scales (0.01)
for eps in epss:
    op_num_tmp = (1+eps)*f_lam*1*(mean_ot+1)/24
    tmp.append(round(op_num_tmp,2))
    
error = max(abs(np.array(tmp)-np.array(op_nums)))
print(f'op_num error: {error}')
test_batch_wpic(jobs, jobs_prob, mean_ot, total_ot, total_jobs, 
                epss, time_span = 300, f_lam = f_lam, f_rls = f_rls, 
                poisson = True, var_op = True, 
                cus_num=1, pause_probs = [0,0.5,1], code=f'12.10_{k}ot_EFop', 
                runs = 20, plots = [True, False, False, False])
# Out:
# c = 5.252 k' = 5.0
# used 8 iterations
# 86.50360205831905
# op_num error: 0.009999999999999787
# setup completed
#
# total jobs = 2915
# f_lam = 2, originally 9.716666666666667
# f_rls time = 43 hours
# mean ot = 85.50360205831905 hours
# test size = 93
# poisson = True
# var_op = True
# cus_num = 1
# pause_prob = [0, 0.5, 1]
# job_scale = 2
# ##### 1/93 finished #####
# ##### time used: 8.08 sec #####
# ##### 2/93 finished #####
# ##### time used: 8.32 sec #####
# ##### 3/93 finished #####
# ##### time used: 8.49 sec #####
# ##### 4/93 finished #####
# ##### time used: 8.02 sec #####
# ##### 5/93 finished #####
# ##### time used: 8.2 sec #####
# ##### 6/93 finished #####
# ##### time used: 8.52 sec #####
# ##### 7/93 finished #####
# ##### time used: 7.95 sec #####
# ##### 8/93 finished #####
# ##### time used: 8.18 sec #####
# ##### 9/93 finished #####
# ##### time used: 8.52 sec #####
# ##### 10/93 finished #####
# ##### time used: 7.98 sec #####
# ##### 11/93 finished #####
# ...

# %%
k = 2
path = "../ecldata/ecldata_without_float.csv"
c, f_lam, f_rls = get_multiplier(k, tol = 1e-3, check = True, path = path)
jobs, jobs_prob, mean_ot, total_ot, total_jobs = csv_to_jobs(path, mul=c)
'''rounding up/down lambda acceptable?'''
print(mean_ot+1)
#op_num = (1+eps)*f_lam*(cus_num*1+cus_num*mean_ot)/24

op_nums = csv_to_data("level_curve_dt/1.0ot_op_10ecl_pois_var_1cus.csv",attr='op_num')

tmp = []
epss = np.linspace(0.3,0,31) 
#0.5-0, 26 discrete scales (0.01)
for eps in epss:
    op_num_tmp = (1+eps)*f_lam*1*(mean_ot+1)/24
    tmp.append(round(op_num_tmp,2))
    
error = max(abs(np.array(tmp)-np.array(op_nums)))
print(f'op_num error: {error}')
test_batch_wpic(jobs, jobs_prob, mean_ot, total_ot, total_jobs, 
                epss, time_span = 300, f_lam = f_lam, f_rls = f_rls, 
                poisson = True, var_op = True, 
                cus_num=1, pause_probs = [0,0.5,1], code=f'12.10_{k}ot_EFop', 
                runs = 20, plots = [True, False, False, False])
# Out:
# c = 2.063 k' = 2.0
# used 3 iterations
# 34.59451114922813
# op_num error: 0.009999999999999787
# setup completed
#
# total jobs = 2915
# f_lam = 5, originally 9.716666666666667
# f_rls time = 17 hours
# mean ot = 33.59451114922813 hours
# test size = 93
# poisson = True
# var_op = True
# cus_num = 1
# pause_prob = [0, 0.5, 1]
# job_scale = 5
# ##### 1/93 finished #####
# ##### time used: 16.14 sec #####
# ##### 2/93 finished #####
# ##### time used: 16.42 sec #####
# ##### 3/93 finished #####
# ##### time used: 16.6 sec #####
# ##### 4/93 finished #####
# ##### time used: 15.97 sec #####
# ##### 5/93 finished #####
# ##### time used: 16.46 sec #####
# ##### 6/93 finished #####
# ##### time used: 16.58 sec #####
# ##### 7/93 finished #####
# ##### time used: 15.98 sec #####
# ##### 8/93 finished #####
# ##### time used: 16.38 sec #####
# ##### 9/93 finished #####
# ##### time used: 16.79 sec #####
# ##### 10/93 finished #####
# ##### time used: 16.19 sec #####
# ...

# %%
k = 0.5
path = "../ecldata/ecldata_without_float.csv"
c, f_lam, f_rls = get_multiplier(k, tol = 1e-3, check = True, path = path)
jobs, jobs_prob, mean_ot, total_ot, total_jobs = csv_to_jobs(path, mul=c)
'''rounding up/down lambda acceptable?'''
print(mean_ot+1)
#op_num = (1+eps)*f_lam*(cus_num*1+cus_num*mean_ot)/24

op_nums = csv_to_data("level_curve_dt/1.0ot_op_10ecl_pois_var_1cus.csv",attr='op_num')

tmp = []
epss = np.linspace(0.3,0,31) 
#0.5-0, 26 discrete scales (0.01)
for eps in epss:
    op_num_tmp = (1+eps)*f_lam*1*(mean_ot+1)/24
    tmp.append(round(op_num_tmp,2))
    
error = max(abs(np.array(tmp)-np.array(op_nums)))
print(f'op_num error: {error}')
test_batch_wpic(jobs, jobs_prob, mean_ot, total_ot, total_jobs, 
                epss, time_span = 300, f_lam = f_lam, f_rls = f_rls, 
                poisson = True, var_op = True, 
                cus_num=1, pause_probs = [0,0.5,1], code=f'12.10_{k}ot_EFop', 
                runs = 20, plots = [True, False, False, False])
# Out:
# c = 0.468 k' = 0.5
# used 2 iterations
# 8.652830188679246
# op_num error: 0.010000000000001563
# setup completed
#
# total jobs = 2915
# f_lam = 20, originally 9.716666666666667
# f_rls time = 4 hours
# mean ot = 7.652830188679245 hours
# test size = 93
# poisson = True
# var_op = True
# cus_num = 1
# pause_prob = [0, 0.5, 1]
# job_scale = 20
# ##### 1/93 finished #####
# ##### time used: 45.35 sec #####
# ##### 2/93 finished #####
# ##### time used: 45.95 sec #####
# ##### 3/93 finished #####
# ##### time used: 46.38 sec #####
# ##### 4/93 finished #####
# ##### time used: 45.15 sec #####
# ##### 5/93 finished #####
# ##### time used: 46.15 sec #####
# ##### 6/93 finished #####
# ##### time used: 46.34 sec #####
# ##### 7/93 finished #####
# ##### time used: 45.28 sec #####
# ##### 8/93 finished #####
# ##### time used: 45.9 sec #####
# ##### 9/93 finished #####
# ##### time used: 46.44 sec #####
# ##### 10/93 finished #####
# ##### time used: 45.26 sec #####
# ...

# %%
k = 1
path = "../ecldata/ecldata_without_float.csv"
c, f_lam, f_rls = get_multiplier(k, tol = 1e-3, check = True, path = path)
jobs, jobs_prob, mean_ot, total_ot, total_jobs = csv_to_jobs(path, mul=1)
'''rounding up/down lambda acceptable?'''
print(mean_ot+1)
#op_num = (1+eps)*f_lam*(cus_num*1+cus_num*mean_ot)/24

op_nums = csv_to_data("level_curve_dt/1.0ot_op_10ecl_pois_var_1cus.csv",attr='op_num')

tmp = []
epss = np.linspace(0.3,0,31) 
#0.5-0, 26 discrete scales (0.01)
for eps in epss:
    op_num_tmp = (1+eps)*f_lam*1*(mean_ot+1)/24
    tmp.append(round(op_num_tmp,2))
    
error = max(abs(np.array(tmp)-np.array(op_nums)))
print(f'op_num error: {error}')
test_batch_wpic(jobs, jobs_prob, mean_ot, total_ot, total_jobs, 
                epss, time_span = 300, f_lam = f_lam, f_rls = f_rls, 
                poisson = True, var_op = True, 
                cus_num=1, pause_probs = [0,0.5,1], code=f'12.10_{k}ot_EFop',
                runs = 20, plots = [True, False, False, False])
# Out:
# c = 1.0 k' = 1.0
# used 1 iterations
# 17.301200686106345
# op_num error: 0.0
# setup completed
#
# total jobs = 2915
# f_lam = 10, originally 9.716666666666667
# f_rls time = 8 hours
# mean ot = 16.301200686106345 hours
# test size = 93
# poisson = True
# var_op = True
# cus_num = 1
# pause_prob = [0, 0.5, 1]
# job_scale = 10
# ##### 1/93 finished #####
# ##### time used: 27.73 sec #####
# ##### 2/93 finished #####
# ##### time used: 28.15 sec #####
# ##### 3/93 finished #####
# ##### time used: 28.41 sec #####
# ##### 4/93 finished #####
# ##### time used: 27.71 sec #####
# ##### 5/93 finished #####
# ##### time used: 28.1 sec #####
# ##### 6/93 finished #####
# ##### time used: 28.47 sec #####
# ##### 7/93 finished #####
# ##### time used: 27.57 sec #####
# ##### 8/93 finished #####
# ##### time used: 28.15 sec #####
# ##### 9/93 finished #####
# ##### time used: 28.31 sec #####
# ##### 10/93 finished #####
# ##### time used: 27.72 sec #####
# ##### 11/93 finished #####
# ...
